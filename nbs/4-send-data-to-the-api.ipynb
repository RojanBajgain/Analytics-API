# %%
import requests

# %%
path = "/api/events"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

headers = {"Content-Type": "application/json"}
response = requests.post(create_endpoint, json={"page": "/test"})
print(response.headers)
print("ok", response.ok)

if response.ok:
    data = response.json()
    print(data, type(data), data.get("items"))
else:
    print(response.text)
# Out:
# {'date': 'Tue, 10 Mar 2026 11:30:48 GMT', 'server': 'uvicorn', 'content-length': '56', 'content-type': 'application/json'}
# ok True
# {'id': 123, 'page': '/test', 'description': 'My Description'} <class 'dict'> None

# %%
detail_path = "/api/events/12/"
detail_endpoint = f"{base_url}{detail_path}"

headers = {
    "Content-Type": "application/json"
    }
response = requests.put(detail_endpoint, json={"description": "hello world"}, headers=headers)
print(response.headers)
print("ok", response.ok)

if response.ok:
    data = response.json()
    print(data, type(data), data.get("items"))
else:
    print(response.text)
# Out:
# {'date': 'Tue, 10 Mar 2026 11:30:48 GMT', 'server': 'uvicorn', 'content-length': '47', 'content-type': 'application/json'}
# ok True
# {'id': 12, 'page': '', 'description': 'hello world'} <class 'dict'> None
